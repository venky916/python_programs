# %%
x=eval(input())
type(x)
# Out:
# hello
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a7d8d194cc24> in <cell line: 1>()
# ----> 1 x=eval(input())
#       2 type(x)
#
# <string> in <module>
#
# NameError: name 'hello' is not defined

# %%
# from functools import reduce

# lst=[1,2,3,4,5]

# k=reduce(lambda x,y:x+y ,lst)

# print(k)

# num=5
# print(f'{num}is even ') if num%2==0 else print(f'{num} is odd')

# def square(num):
#     return num**2

# lst=[1,2,3,4,5]

# # k=map(square,lst)
# # for val in k:
# #     print(val,type(val))

# lst1=[1,2,3,4,5]

# s=filter(lambda x: x%2!=0 ,lst1)

# for val in s:
#     print(val,type(val))

li={1:'hell',2:'world',3:'!'}

a=iter(li)
# print(next(a))
# print(next(a))
# print(next(a))
for val in a:
    print(val,)
# Out:
# 1
# 2
# 3
