# %%
x=list("1234")
print(x)
# Out:
# ['1', '2', '3', '4']

# %%
lst=[1,2,3,4,5]
print(lst[:0])
print(lst[-1:-3])
# Out:
# []
# []

# %%
str1='Python'
print(str1.replace('p','j'))
print(str1)
# Out:
# Python
# Python

# %%
x=22
print(x.bit_count())
print(x.bit_length())
# Out:
# 3
# 5

# %%
lst=[1,2,3]
lst.append('string')
lst.extend('string')

print(lst)
# Out:
# [1, 2, 3, 'string', 's', 't', 'r', 'i', 'n', 'g']

# %%
lst=[1,2,3,[4,5,6,[7,8,9]]]
print(lst[3][3][:])
print(lst[3][3][2])
# Out:
# [7, 8, 9]
# 9

# %%
str1='hello'
print(str1)
del str1
print(str1)
# Out:
# hello
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-d64017afb1a9> in <cell line: 4>()
#       2 print(str1)
#       3 del str1
# ----> 4 print(str1)
#
# NameError: name 'str1' is not defined

# %%
lst=[1,2,3]
del lst[1]
print(lst)
# Out:
# [1, 3]

# %%
lst=[1,2,3]
lst1=lst
lst1[2]=4
print(lst)
print(lst1)
# Out:
# [1, 2, 4]
# [1, 2, 4]

# %%
lst=[1,2,3]
lst1=lst.copy()
lst1[2]=4
print(lst)
print(lst1)
# Out:
# [1, 2, 3]
# [1, 2, 4]

# %%
lst=[1,2,3]
lst1=lst.copy()
lst1[2]=4
print(lst)
print(lst1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-26026244a0e9> in <cell line: 2>()
#       1 lst=[1,2,3]
# ----> 2 lst1=lst.deepcopy()
#       3 lst1[2]=4
#       4 print(lst)
#       5 print(lst1)
#
# AttributeError: 'list' object has no attribute 'deepcopy'

# %%
lst=[4,5,2,1,7,9,0]
lst.reverse()
print(lst)
# Out:
# [0, 9, 7, 1, 2, 5, 4]

# %%
lst=[4,5,2,1,7,9,0]
var=reversed(lst)
print(lst)
print(var)
# Out:
# [4, 5, 2, 1, 7, 9, 0]
# <list_reverseiterator object at 0x7f496a54ab60>

# %%
lst=[4,5,2,1,7,9,0]
lst.sort()
print(lst)
# Out:
# [0, 1, 2, 4, 5, 7, 9]

# %%
lst=["geeksforgeeks", "geeks", "geek", "geezer"]
lst.sort()
print(lst)
# Out:
# ['geek', 'geeks', 'geeksforgeeks', 'geezer']

# %%
lst=[4,5,2,1,7,9,0]
var=sorted(lst)
print(lst)
print(var)
# Out:
# [4, 5, 2, 1, 7, 9, 0]
# [0, 1, 2, 4, 5, 7, 9]

# %%
dic={'Balu':{1:['Reddy','420']}}

print(dic['Balu'])

print(dic['Balu'][1])

print(dic['Balu'][1][1])
# Out:
# {1: ['Reddy', '420']}
# ['Reddy', '420']
# 420

# %%
# dic=dict([(1,'hello'),(2,'world')])
# dic[2]='world!'
# dic[3]='shit'

# print(dic)
#########################################################

# dic=dict(a='hello', b='world')

# dic['b']='world!'
# dic['c']='shit'

# print(dic)


dic=dict(1='hello',2='world')

dic['2']='world!'
dic['3']='shit'

print(dic)
# Out:
#   File "<ipython-input-8-965be3b11d07>", line 16
#     dic=dict(1='hello',2='world')
#              ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
def func(*args):
  print(args)

func('hello','world','!')
func(('hello','world','!'))
func(['hello','world','!'])
# Out:
# ('hello', 'world', '!')
# (('hello', 'world', '!'),)
# (['hello', 'world', '!'],)

# %%
def lst(*args):
  lst=[]
  for var in args:
    lst.append(var)
  return lst

k=lst('hello','world','!')
print(k)
# Out:
# ['hello', 'world', '!']

# %%
def fun1():
  print('outter')
  def fun2():
    print('inner')
  fun2()

x=fun1()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-191410bf56ad> in <cell line: 7>()
#       5   fun2()
#       6
# ----> 7 x=fun2()
#
# NameError: name 'fun2' is not defined

# %%
a=5
def foo():
	name = "geek" # Our local variable
  global a
  a=10
  print(a)
	def bar():
		nonlocal name		 # Reference name in the upper scope
		name = 'GeeksForGeeks' # Overwrite this variable
    global a
    a='fun'
		print(name)
    print(a)

	# Calling inner function
	bar()


	# Printing local variable
	print(name)
  print(a)

foo()
print(a)
# Out:
#   File "<tokenize>", line 4
#     global a
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
a=5
def foo():
    name = "geek" # Our local variable
    global a
    a=10
    print(a)
    def bar():
            nonlocal name		 # Reference name in the upper scope
            name = 'GeeksForGeeks' # Overwrite this variable
            global a
            a='fun'
            print(name)
            print(a)

	# Calling inner function
    bar()


	# Printing local variable
    print(name)
    print(a)

foo()
print(a)

# %%
# Calling function
result = enumerate([1,2,3],2)
# Displaying result
print(result)
print(list(result))
# Out:
# <enumerate object at 0x7eb9aca15d80>
# [(2, 1), (3, 2), (4, 3)]

# %%
x=iter(range(1,10))
print(x)
print(next(x))
# Out:
# <range_iterator object at 0x798088269a10>
# 1
